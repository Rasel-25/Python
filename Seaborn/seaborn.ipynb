# %% [markdown]
# # Introduction to Seaborn – Python
# Seaborn is an amazing visualization library for statistical graphics plotting in Python.
#
# It provides beautiful default styles and color palettes to make statistical plots more attractive.
#
# It is built on the top of matplotlib library and also closely integrated to the data structures from pandas.
#
# Seaborn aims to make visualization the central part of exploring and understanding data.
#
# It provides dataset-oriented APIs, so that we can switch between different visual representations for same variables for better understanding of dataset.

# %%
import numpy as np 
import seaborn as sns
import pandas as pd 
import matplotlib as plt

# %%
sales = pd.read_excel('sales.xlsx')
sales.head()

# %%
sns.relplot('Sales','Profit',data=sales) # relational plot which return relation between variables

# %%
# Hue is one of the main properties (called color appearance parameters) of a color, defined technically 
sns.set(style="white")
sns.relplot('Sales','Profit',data=sales, hue='Order Priority') #

# %%
sns.relplot('Sales','Profit',data=sales, hue='Order Priority',style='Ship Mode') #style  return different shapes
sns.set(style="white")

# %%
sns.relplot('Sales','Profit',data=sales,hue='Order Priority',size='Discount',sizes=(50,300) ) # size='Discount increase the according to Discount
sns.set(style="white") # sizes=(25,200) which increase points

# %% [markdown]
# kind:  str, optional
#
# The kind of plot to draw, corresponds to the name of a categorical axes-level plotting function. Options are: “strip”, “swarm”, “box”, “violin”, “boxen”, “point”, “bar”, or “count”.

# %%
sns.relplot('Order Date','Sales',data=sales,kind='line')

# %%
sales.head()
# Out:
#    Row ID  Order ID Order Date Order Priority  Order Quantity       Sales  \
# 0     1.0       3.0 2010-10-13            Low             6.0    261.5400
# 1    49.0     293.0 2012-10-01           High            49.0  10123.0200
# 2    50.0     293.0 2012-10-01           High            27.0    244.5700
# 3    80.0     483.0 2011-07-10           High            30.0   4965.7595
# 4    85.0     515.0 2010-08-28  Not Specified            19.0    394.2700
#
#    Discount       Ship Mode     Profit  Unit Price  ...  Province   Region  \
# 0      0.04     Regular Air  -213.2500       38.94  ...   Nunavut  Nunavut
# 1      0.07  Delivery Truck   457.8100      208.16  ...   Nunavut  Nunavut
# 2      0.01     Regular Air    46.7075        8.69  ...   Nunavut  Nunavut
# 3      0.08     Regular Air  1198.9710      195.99  ...   Nunavut  Nunavut
# 4      0.08     Regular Air    30.9400       21.78  ...   Nunavut  Nunavut
#
#   Customer Segment Product Category            Product Sub-Category  \
# 0   Small Business  Office Supplies          Storage & Organization
# 1         Consumer  Office Supplies                      Appliances
# 2         Consumer  Office Supplies  Binders and Binder Accessories
# 3        Corporate       Technology    Telephones and Communication
# 4         Consumer  Office Supplies                      Appliances
#
#                                         Product Name Product Container  \
# 0   Eldon Base for stackable storage shelf, platinum         Large Box
# 1  1.7 Cubic Foot Compact "Cube" Office Refrigera...        Jumbo Drum
# 2   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl         Small Box
# 3                                               R380         Small Box
# 4                           Holmes HEPA Air Purifier        Medium Box
#
#   Product Base Margin  Ship Date  year
# 0                0.80 2010-10-20  2010
# 1                0.58 2012-10-02  2012
# 2                0.39 2012-10-03  2012
# 3                0.58 2011-07-12  2011
# 4                0.50 2010-08-30  2010
#
# [5 rows x 22 columns]

# %%
sales['year']=sales['Order Date'].dt.year # find out all unique date
sales.year.unique()
# Out:
# array([2010, 2012, 2011, 2009], dtype=int64)

# %%
sns.relplot('year','Sales',data=sales,kind='line')# getting relation between year and sales according to line graph

# %%
sns.relplot('year','Sales',data=sales,kind='line',ci=None)# getting relation between year and sales according to line graph but confidence interval(ci) none
# Out:
# C:\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.relplot('year','Sales',data=sales,kind='line',ci='sd')# getting relation between year and sales according to line graph with standard deviasion(sd)
# Out:
# C:\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.relplot('year','Sales',data=sales,kind='line',estimator=None) # getting relation between year and sales according to line graph without estimator
# Out:
# C:\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.relplot('year','Sales',data=sales,kind='line',estimator=sum) # getting relation between year and sales according to line graph with estimator sum
# Out:
# C:\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.catplot('year','Sales',data=sales,kind='violin') # getting relation between year and sales according to violin graph
